# %%
def salvar_html(html, filename):
    """Salva o resultado de uma requisição para visualização (sem css) no browser
    """
    with open(filename,'w') as myf:
        myf.write(html)

# %% [markdown]
# ### Setup do browser

# %% [markdown]
# Imports e constantes

# %%
import mechanize
from urllib import urlencode
from bs4 import BeautifulSoup as bsoup
#URLs
base_url = "https://www.ncbi.nlm.nih.gov"

# %%
#Browser
driver = mechanize.Browser()
driver.set_handle_robots(False)
driver.addheaders = [('User-agent',
                    'Mozilla/5.0 (compatible; ABrowse 0.4; Syllable)')]

clear_cookies = driver._ua_handlers['_cookies'].cookiejar.clear

# %% [markdown]
# ### Encontrando os artigos na primeira página

# %%
### Pesquisar
pesquisa = {'term':'risk AND machine learning'}
clear_cookies()
resposta = driver.open(base_url + '/pmc/', urlencode(pesquisa))

### Pegar resultados
soup = bsoup(resposta.read(), "html5lib")
#Título da página
print soup.findAll('title')[0].text
# Número da página
print soup.findAll('input',id='pageno')[0]['value'] + '\n'
#Títulos dos papers encontrados
links = soup.findAll("div", {"class":"title"})
print '\n\n'.join([link.text for link in links[:5]])
articles = links
# Out:
# risk AND machine learning - PMC - NCBI
# 1
#
# Progressive sampling-based Bayesian optimization for efficient and automatic machine learning model selection
#
# MLBCD: a machine learning tool for big clinical data
#
# Can machine-learning improve cardiovascular risk prediction using routine clinical data?
#
# Machine Learning and Radiology
#
# Accuracy of automated classification of major depressive disorder as a function of symptom severity

# %% [markdown]
# ### Encontrando os artigos depois da primeira página

# %%
from imports_pmc import _querystring, _pageno
### Pesquisar, setando o request com o número da página
_querystring[_pageno] = 3
resposta = driver.open("https://www.ncbi.nlm.nih.gov/pmc/",
                       urlencode(_querystring)
                      )

### Pegar resultados
soup = bsoup(resposta.read(), "html5lib")
#Título da página
print soup.findAll('title')[0].text
# Número da página
print soup.findAll('input',id='pageno')[0]['value'] + '\n'
#Títulos dos papers encontrados
links = soup.findAll("div", {"class":"title"})
print '\n\n'.join([link.text[:65] + '...' for link in links[:3]])
# Out:
# risk AND machine learning - PMC - NCBI
# 3
#
# Machine Learning Algorithms Outperform Conventional Regression Mo...
#
# Using Machine Learning and Natural Language Processing Algorithms...
#
# A Cognitive Machine Learning Algorithm for Cardiac Imaging: A Pil...

# %%
[link.findAll('a', href=True)[0]['href'] for link in links[:3]]
# Out:
# [u'/pmc/articles/PMC3335189/',
#  u'/pmc/articles/PMC4516296/',
#  u'/pmc/articles/PMC4336000/']

# %% [markdown]
# ### Pegando as keywords

# %% [markdown]
# e mais algum parágrafo

# %%
for article in articles[:1]:
    url = base_url + article.findAll('a', href=True)[0]['href']
    resposta = driver.open(url)
    soup = bsoup(resposta.read(), "html5lib")
    #Título da página
    print soup.findAll('title')[0].text[:65] + '...\n'
    try:
        print soup.findAll('span',{"class":"kwd-text"})[0].text+ '...\n'
    except:
        pass
    print soup.findAll('p',{"class":"p p-first-last"})[0].text+ '...\n'
    
    print '\n\n'
# Out:
# Progressive sampling-based Bayesian optimization for efficient an...
#
# Automatic machine learning model selection, Bayesian optimization, Progressive sampling, Clinical big data...
#
# Machine learning is broadly used for clinical data analysis. Before training a model, a machine learning algorithm must be selected. Also, the values of one or more model parameters termed hyper-parameters must be set. Selecting algorithms and hyper-parameter values requires advanced machine learning knowledge and many labor-intensive manual iterations. To lower the bar to machine learning, miscellaneous automatic selection methods for algorithms and/or hyper-parameter values have been proposed. Existing automatic selection methods are inefficient on large data sets. This poses a challenge for using machine learning in the clinical big data era....

# %% [markdown]
# ### Cruzando as palavras-chave

# %% [markdown]
# ou seja, fazendo a busca de par em par de palavras-chave e salvando os resultados

# %%
from imports_pmc import _querystring, _pageno
from datetime import datetime
from time import time

domain_specific = [
    'Coronary Artery Disease',
    'Arterial Coronary Syndrome',
    'Patient Assessment',
    'Risk Stratification',
    'Risk Score',
    'Angiography',
    'Tomography'
]
keywords = [
    'Image processing',
    'image segmentation',
    'Artificial Intelligence',
    'Deep Learning'
]
articles_per_page = 20
page_depth = 1

stems = {}

driver = mechanize.Browser()
driver.set_handle_robots(False)
driver.addheaders = [('User-agent',
                    'Mozilla/5.0 (compatible; ABrowse 0.4; Syllable)')]

clear_cookies = driver._ua_handlers['_cookies'].cookiejar.clear

ts = time()
for domain in domain_specific:
    for keyword in keywords:
        term = ' AND '.join((domain, keyword))
        research = {'term': term}
        stem = []
        append = stem.append
        ###
        ### Primeira página
        ###
        clear_cookies()
        print '[*]resgatando titulos de',term,
        resposta = driver.open(base_url + '/pmc/', urlencode(research))
        print 'ok'
        # Pegar resultados
        soup = bsoup(resposta.read(), "html5lib")
        # Articles encontrados
        articles = soup.findAll("div", {"class":"title"})
        
        for article in articles[:articles_per_page]:
            # Reunir conteúdo de cada paper
            content = {}
            url = base_url + article.findAll('a', href=True)[0]['href']
            print '[-]lendo ',article.text[:65].replace('\n',' ') +'(...)',
            resposta = driver.open(url)
            print 'ok'
            soup = bsoup(resposta.read(), "html5lib")
            content['title'] = soup.findAll('title')[0].text
            content['url'] = url
            
            try:
                content['kwd'] = soup.findAll('span',{"class":"kwd-text"})[0].text
            except:
                content['kwd'] = '-'
            try:
                content['p'] = soup.findAll('p',{"class":"p p-first-last"})[0].text
                content['p'] += soup.findAll('p',{"class":"p p-first-last"})[1].text
            except:
                content['p'] = '-'
            
            append(content)
            
        ###
        ### Segunda página
        ###
        for page in range(2,page_depth + 1):
            _querystring[_pageno] = page
            resposta = driver.open(base_url + '/pmc/', urlencode(_querystring))
            
            # Pegar resultados
            soup = bsoup(resposta.read(), "html5lib")
            # Articles encontrados
            articles = soup.findAll("div", {"class":"title"})
            
            for article in articles[:articles_per_page]:
                # Reunir conteúdo de cada paper
                content = {}
                url = base_url + article.findAll('a', href=True)[0]['href']
                print '[-]lendo ',article.text[:65].replace('\n',' ') +'(...)',
                resposta = driver.open(url)
                print 'ok'
                soup = bsoup(resposta.read(), "html5lib")
                content['title'] = soup.findAll('title')[0].text
                content['url'] = url
                
                try:
                    content['kwd'] = soup.findAll('span',{"class":"kwd-text"})[0].text
                except:
                    content['kwd'] = '-'
                try:
                    content['p'] = soup.findAll('p',{"class":"p p-first-last"})[0].text
                    content['p'] += soup.findAll('p',{"class":"p p-first-last"})[1].text
                except:
                    content['p'] = '-'

                append(content)
                
        stems[term] = stem
        
print "Tempo de execução:", time() - ts
filename = "stems" + str(datetime.now()).replace(' ','-') + '.txt'
with open(filename, 'w') as myf:
    myf.write(str(stems))
print '[*] fim: resultados salvos em',filename
# Out:
# [*]resgatando titulos de Coronary Artery Disease AND Image processing ok
# [-]lendo  Cardiac magnetic resonance and computed tomography angiography fo(...) ok
# [-]lendo  Noninvasive FFR derived from coronary CT angiography in the manag(...) ok
# [-]lendo  Assessment of stable coronary artery disease by cardiovascular ma(...) ok
# [-]lendo  Total Coronary Atherosclerotic Plaque Burden Assessment by CT Ang(...) ok
# [-]lendo  Visualization of Coronary Wall Atherosclerosis in Asymptomatic Su(...) ok
# [-]lendo  Coronary CT angiography: current status and continuing challenges(...) ok
# [-]lendo  Cardiac CT vs. Stress Testing in Patients with Suspected Coronary(...) ok
# [-]lendo  Regional Coronary Endothelial Function is Closely Related to Loca(...) ok
# [-]lendo  3D multimodal cardiac data reconstruction using angiography and c(...) ok
# [-]lendo  Feasibility of Coronary Artery Wall Thickening Assessment in Asym(...) ok
# [-]lendo  All-cause mortality benefit of coronary revascularization vs. med(...) ok
# [-]lendo  Diagnostic performance of image navigated coronary CMR angiograph(...) ok
# [-]lendo  Relationship between Calcium Score and Myocardial Scintigraphy in(...) ok
# [-]lendo  Stress Echocardiography for the Diagnosis of Coronary Artery Dise(...) ok
# [-]lendo  Myocardial blood flow quantification for evaluation of coronary a(...) ok
# [-]lendo  Noninvasive Imaging of Atherosclerotic Plaque Progression: Status(...) ok
# [-]lendo  Inheritance of coronary artery disease in men: an analysis of the(...) ok
# [-]lendo  Serum protein profiles predict coronary artery disease in symptom(...) ok
# [-]lendo  The Association of Brachial-Ankle Pulse Wave Velocity with Corona(...) ok
# [-]lendo  An integrated approach to coronary heart disease diagnosis and cl(...) ok
# [*]resgatando titulos de Coronary Artery Disease AND image segmentation ok
# [-]lendo  3D multimodal cardiac data reconstruction using angiography and c(...) ok
# [-]lendo  Computerized analysis of coronary artery disease: Performance eva(...) ok
# [-]lendo  Computer Vision Techniques for Transcatheter Intervention(...) ok
# [-]lendo  Reconstruction of stented coronary arteries from optical coherenc(...) ok
# [-]lendo  Noninvasive FFR derived from coronary CT angiography in the manag(...) ok
# [-]lendo  Coronary artery analysis: Computer-assisted selection of best-qua(...) ok
# [-]lendo  Noninvasive Imaging of Atherosclerotic Plaque Progression: Status(...) ok
# [-]lendo  CT-based Diagnosis of Diffuse Coronary Artery Disease on the Basi(...) ok
# [-]lendo  Lack of Association Between Epicardial Fat Volume and Extent of C(...) ok
# [-]lendo  Visualization of Coronary Wall Atherosclerosis in Asymptomatic Su(...) ok
# [-]lendo  A Collaborative Resource to Build Consensus for Automated Left Ve(...) ok
# [-]lendo  Automated coronary artery tree extraction in coronary CT angiogra(...) ok
# [-]lendo  A review of heart chamber segmentation for structural and functio(...) ok
# [-]lendo  Multimodality image fusion for diagnosing coronary artery disease(...) ok
# [-]lendo  IVUS Validation of Patient Coronary Artery Lumen Area Obtained fr(...) ok
# [-]lendo  ACUTE RETINAL ARTERIAL OCCLUSIVE DISORDERS(...) ok
# [-]lendo  B - Scientific Sessions(...) ok
# [-]lendo   2014 Guidelines of Taiwan Society of Cardiology (TSOC) for the M(...) ok
# [*]resgatando titulos de Patient Assessment AND Image processing ok
# [-]lendo  A Primer on Observational Measurement(...) ok
# [-]lendo  Development of Abbreviated Nine-item Forms of the Raven’s Standar(...) ok
# [-]lendo  Quantitative assessment of the impact of biomedical image acquisi(...) ok
# [-]lendo  Viewpoints on Medical Image Processing: From Science to Applicati(...) ok
# [-]lendo  Simultaneous Tumor Segmentation, Image Restoration, and Blur Kern(...) ok
# [-]lendo  Towards the clinical implementation of iterative low-dose cone-be(...) ok
# [-]lendo  5th International Symposium on Focused Ultrasound: North Bethesda(...) ok
# [-]lendo  UEG Week 2015 Poster Presentations(...) ok
# [-]lendo  International Society for Therapeutic Ultrasound Conference 2016:(...) ok
# [-]lendo  Quantification in cardiac MRI: advances in image acquisition and (...) ok
# [-]lendo  Proceedings of the 3rd IPLeiria’s International Health Congress: (...) ok
# [-]lendo  The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)(...) ok
# [-]lendo  Improving Low-dose Cardiac CT Images based on 3D Sparse Represent(...) ok
# [-]lendo  Abstracts for the 15th International Congress on Schizophrenia Re(...) ok
# [-]lendo  Quantitative assessment of susceptibility weighted imaging proces(...) ok
# [-]lendo  Comparison of visual grading and free-response ROC analyses for a(...) ok
# [-]lendo  Fast parallel image registration on CPU and GPU for diagnostic cl(...) ok
# [-]lendo  A Review of Algorithms for Segmentation of Optical Coherence Tomo(...) ok
# [-]lendo  Task-based measures of image quality and their relation to radiat(...) ok
# [-]lendo  Using the virtual reality device Oculus Rift for neuropsychologic(...) ok
# [*]resgatando titulos de Patient Assessment AND image segmentation ok
# [-]lendo  The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)(...) ok
# [-]lendo  Robust Nucleus/Cell Detection and Segmentation in Digital Patholo(...) ok
# [-]lendo  Segmentation and Image Analysis of Abnormal Lungs at CT: Current (...) ok
# [-]lendo  MRI Segmentation of the Human Brain: Challenges, Methods, and App(...) ok
# [-]lendo  A Learning-Based Wrapper Method to Correct Systematic Errors in A(...) ok
# [-]lendo  A Review on Segmentation of Positron Emission Tomography Images(...) ok
# [-]lendo  Evaluation of a deep learning approach for the segmentation of br(...) ok
# [-]lendo  Simultaneous Tumor Segmentation, Image Restoration, and Blur Kern(...) ok
# [-]lendo  A review of heart chamber segmentation for structural and functio(...) ok
# [-]lendo  A Review on Automatic Mammographic Density and Parenchymal Segmen(...) ok
# [-]lendo  Interactive Outlining of Pancreatic Cancer Liver Metastases in Ul(...) ok
# [-]lendo  Vision 20/20: Perspectives on automated image segmentation for ra(...) ok
# [-]lendo  A Methodology for Texture Feature-based Quality Assessment in Nuc(...) ok
# [-]lendo  Semiautomated segmentation of head and neck cancers in 18F-FDG PE(...) ok
# [-]lendo  Multi-Atlas Segmentation of Biomedical Images: A Survey(...) ok
# [-]lendo  Comparative performance evaluation of automated segmentation meth(...) ok
# [-]lendo  Structured learning algorithm for detection of nonobstructive and(...) ok
# [-]lendo  Tungsten Oxide Nanorods: An Efficient Nanoplatform for Tumor CT I(...) ok
# [-]lendo   Three-Dimensional Modelling of the Middle-Ear Ossicular Chain Us(...) ok
# [-]lendo  Fifty years of computer analysis in chest imaging: rule-based, ma(...) ok
# [-]lendo  Deep feature learning for automatic tissue classification of coro(...) ok
# Tempo de execução: 3029.4885571
# [*] fim: resultados salvos em stems2017-11-30-17:21:40.768064.txt

# %% [markdown]
# ### Rearranjando o código pra fazer multithreading

# %%
def resgatar_titulos(termo, depth_paginas=1, limite=20):
    driver = mechanize.Browser()
    driver.set_handle_robots(False)
    driver.addheaders = [('User-agent',
                        'Mozilla/5.0 (compatible; ABrowse 0.4; Syllable)')]
    research = {'term': termo}
    stem = []
    append = stem.append
    ###
    ### Primeira página
    ###
    resposta = driver.open(base_url + '/pmc/', urlencode(research))
    # Pegar resultados
    soup = bsoup(resposta.read(), "html5lib")
    # artigos encontrados
    articles = soup.findAll("div", {"class":"title"})
    ###
    ### Segunda página
    ###
    for page in range(2,depth_paginas + 1):
        _querystring[_pageno] = page
        resposta = driver.open(base_url + '/pmc/', urlencode(_querystring))

        # Pegar resultados
        soup = bsoup(resposta.read(), "html5lib")
        # artigos encontrados
        articles.extend(soup.findAll("div", {"class":"title"}))
        
    for article in articles[:limite]:
        # Reunir conteúdo de cada artigo
        content = {}
        url = base_url + article.findAll('a', href=True)[0]['href']
        print '[*] ',article.text[:65].replace('\n',' ') +'(...)'
        resposta = driver.open(url)
        soup = bsoup(resposta.read(), "html5lib")
        content['title'] = soup.findAll('title')[0].text
        content['url'] = url

        try:
            content['kwd'] = soup.findAll('span',{"class":"kwd-text"})[0].text
        except:
            content['kwd'] = '-'
        try:
            content['p'] = soup.findAll('p',{"class":"p p-first-last"})[0].text
            content['p'] += soup.findAll('p',{"class":"p p-first-last"})[1].text
        except:
            content['p'] = '-'

        append(content)
        
    return stem

# %%
from queue import Queue
from threading import Thread, Lock

class StemWorker(Thread):
    def __init__(self, queue, lock, depth_paginas=1, limite=20):
        Thread.__init__(self)
        self.queue = queue
        self.lock = lock
        self.depth_paginas = depth_paginas
        self.limite = limite

    def run(self):
        while True:
            # Pegar trabalho da fila e começar
            termo = self.queue.get()
            stem = resgatar_titulos(termo,
                                    depth_paginas=self.depth_paginas,
                                    limite=self.limite
                                   )
            with self.lock:
                global thread_stems
                thread_stems[termo] = stem
                self.queue.task_done()

# %%
queue = Queue()
lock = Lock()

thread_stems = {}

ts = time()

for x in range(7):
    worker = StemWorker(queue, lock, limite=20)
    worker.daemon = True
    worker.start()
    
for domain in domain_specific:
    for keyword in keywords:
        term = ' AND '.join((domain, keyword))
        
        queue.put(term)
        
queue.join()
print "Tempo de execução:", time() - ts

filename = "thread_stems" + str(datetime.now()).replace(' ','-') + '.txt'
with open(filename, 'w') as myf:
    myf.write(str(thread_stems))
    print '[*] fim: resultados salvos em',filename
# Out:
# [*]  3D multimodal cardiac data reconstruction using angiography and c(...)
# [*]  Cardiac magnetic resonance and computed tomography angiography fo(...)
# [*]  Abstracts from the 38th Annual Meeting of the Society of General (...)
# [*]  Microstructure-Based Biomechanics of Coronary Arteries in Health (...)
# [*]  Microstructure-Based Biomechanics of Coronary Arteries in Health (...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  Computerized analysis of coronary artery disease: Performance eva(...)
# [*]  Noninvasive FFR derived from coronary CT angiography in the manag(...)
# [*]  ECR 2012 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Computer Vision Techniques for Transcatheter Intervention(...)
# [*]  Heart Disease and Stroke Statistics—2017 Update: A Report From th(...)
# [*]  Assessment of stable coronary artery disease by cardiovascular ma(...)
# [*]  Prevalence of congenital coronary artery anomalies as shown by mu(...)
# [*]  Coronary artery anomalies overview: The normal and the abnormal(...)
# [*]  Reconstruction of stented coronary arteries from optical coherenc(...)
# [*]  Total Coronary Atherosclerotic Plaque Burden Assessment by CT Ang(...)
# [*]  Visualization of Coronary Wall Atherosclerosis in Asymptomatic Su(...)
# [*]  Noninvasive FFR derived from coronary CT angiography in the manag(...)
# [*]  Computed Tomography-Based High-Risk Coronary Plaque Score to Pred(...)
# [*]  Coronary CT angiography: current status and continuing challenges(...)
# [*]  Coronary artery analysis: Computer-assisted selection of best-qua(...)
# [*]  Computational simulations of hemodynamic changes within thoracic,(...)
# [*]  Cardiac CT vs. Stress Testing in Patients with Suspected Coronary(...)
# [*]  Regional Coronary Endothelial Function is Closely Related to Loca(...)
# [*]  B - Scientific Sessions(...)
# [*]  Noninvasive Imaging of Atherosclerotic Plaque Progression: Status(...)
# [*]  Intelligent Approach for Analysis of Respiratory Signals and Oxyg(...)
# [*]  Automated Quantitative Nuclear Cardiology Methods(...)
# [*]  Cardiac imaging: working towards fully-automated machine analysis(...)
# [*]  3D multimodal cardiac data reconstruction using angiography and c(...)
# [*]  CT-based Diagnosis of Diffuse Coronary Artery Disease on the Basi(...)
# [*]  Computer-Assisted Diagnosis of the Sleep Apnea-Hypopnea Syndrome:(...)
# [*]  Improved Accuracy of Myocardial Perfusion SPECT for the Detection(...)
# [*]  Lack of Association Between Epicardial Fat Volume and Extent of C(...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  Feasibility of Coronary Artery Wall Thickening Assessment in Asym(...)
# [*]  Coronary Artery Disease Detection Using a Fuzzy-Boosting PSO Appr(...)
# [*]  Visualization of Coronary Wall Atherosclerosis in Asymptomatic Su(...)
# [*]  All-cause mortality benefit of coronary revascularization vs. med(...)
# [*]  Heart Disease and Stroke Statistics—2017 Update: A Report From th(...)
# [*]  A Collaborative Resource to Build Consensus for Automated Left Ve(...)
# [*]  Comparison of Fully Automated Computer Analysis and Visual Scorin(...)
# [*]  Diagnostic performance of image navigated coronary CMR angiograph(...)
# [*]  Methods to Develop an Electronic Medical Record Phenotype Algorit(...)
# [*]  Automated coronary artery tree extraction in coronary CT angiogra(...)
# [*]  Abstracts from the 37th Annual Meeting of the Society of General (...)
# [*]  Diagnostic accuracy of an artificial neural network compared with(...)
# [*]  Evaluation of a comprehensive cardiovascular magnetic resonance p(...)
# [*]  A review of heart chamber segmentation for structural and functio(...)
# [*]  Relationship between Calcium Score and Myocardial Scintigraphy in(...)
# [*]  Artificial Intelligence in Mitral Valve Analysis(...)
# [*]  ECR 2012 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Stress Echocardiography for the Diagnosis of Coronary Artery Dise(...)
# [*]  Multimodality image fusion for diagnosing coronary artery disease(...)
# [*]  Heart Disease and Stroke Statistics—2011 Update: A Report From th(...)
# [*]  Prediction of Revascularization after Myocardial Perfusion SPECT (...)
# [*]  Imaging Atherosclerosis(...)
# [*]  IVUS Validation of Patient Coronary Artery Lumen Area Obtained fr(...)
# [*]  Combining Personality Traits with Traditional Risk Factors for Co(...)
# [*]  Myocardial blood flow quantification for evaluation of coronary a(...)
# [*]  Coronary Artery Plaque Volume and Obesity in Patients with Diabet(...)
# [*]  Improved accuracy of myocardial perfusion SPECT for detection of (...)
# [*]  Characterizaton of the Vessel Geometry, Flow Mechanics and Wall S(...)
# [*]  An artificial intelligence tool to predict fluid requirement in t(...)
# [*]  Noninvasive Imaging of Atherosclerotic Plaque Progression: Status(...)
# [*]  CT angiography in the diagnosis of cardiovascular disease: a tran(...)
# [*]  Artificial intelligence in medicine.(...)
# [*]  Abstracts from the 36th Annual Meeting of the Society of General (...)
# [*]  Assessment of Inter-Expert Variability and of an Automated Segmen(...)
# [*]  High-Efficiency SPECT MPI: Comparison of Automated Quantification(...)
# [*]  Inheritance of coronary artery disease in men: an analysis of the(...)
# [*]  Diagnostic performance of image navigated coronary CMR angiograph(...)
# [*]  The coronary circulation in exercise training(...)
# [*]  Direct Quantification of Post-Stress-Rest Left Ventricular Motion(...)
# [*]  ECR 2011 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Serum protein profiles predict coronary artery disease in symptom(...)
# [*]  The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)(...)
# [*]  Abstracts from the 36th Annual Meeting of the Society of General (...)
# [*]  Iodinated Contrast Opacification Gradients in Normal Coronary Art(...)
# [*]  The Association of Brachial-Ankle Pulse Wave Velocity with Corona(...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  Myocardial blood flow quantification for evaluation of coronary a(...)
# [*]  Single centre experience of the application of self navigated 3D (...)
# [*]  An integrated approach to coronary heart disease diagnosis and cl(...)
# [*]  ACCF/ACR/AHA/NASCI/SCMR 2010 Expert Consensus Document on Cardiov(...)
# [*]  Genomics era and complex disorders: Implications of GWAS with spe(...)
# [*]  Coronary Arteries in Childhood Heart Disease: Implications for Ma(...)
# [*]  ACCF/ACR/AHA/NASCI/SCMR 2010 Expert Consensus Document on Cardiov(...)
# [*]  Abstracts from the 36th Annual Meeting of the Society of General (...)
# [*]  A Primer on Observational Measurement(...)
# [*]  Abstracts from the 37th Annual Meeting of the Society of General (...)
# [*]  Computed Tomography and Cardiac Magnetic Resonance in Ischemic He(...)
# [*]  Development of Abbreviated Nine-item Forms of the Raven’s Standar(...)
# [*]  Noninvasive Imaging of Atherosclerotic Plaque Progression: Status(...)
# [*]  Quantitative assessment of the impact of biomedical image acquisi(...)
# [*]  Computed Tomography-Based High-Risk Coronary Plaque Score to Pred(...)
# [*]  The diagnostic evaluation of dual-source CT (DSCT) in the diagnos(...)
# [*]  Compensatory enlargement of Ossabaw miniature swine coronary arte(...)
# [*]  Diagnosing Coronary Artery Disease via Data Mining Algorithms by (...)
# [*]  Heart ischaemia–reperfusion induces local up-regulation of vasoco(...)
# [*]  Myocardial blood flow quantification for evaluation of coronary a(...)
# [*]  Viewpoints on Medical Image Processing: From Science to Applicati(...)
# [*]  Cardiac imaging: working towards fully-automated machine analysis(...)
# [*]  A novel hypothesis for atherosclerosis as a cholesterol sulfate d(...)
# [*]  Imaging Atherosclerosis(...)
# [*]  Simultaneous Tumor Segmentation, Image Restoration, and Blur Kern(...)
# [*]  Artificial intelligence: Neural network model as the multidiscipl(...)
# [*]  Abstracts from the 37th Annual Meeting of the Society of General (...)
# [*]  Coronary CT Angiography in Heavily Calcified Coronary Arteries: I(...)
# [*]  The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)(...)
# [*]  Towards the clinical implementation of iterative low-dose cone-be(...)
# [*]  Metabolomics for the masses: The future of metabolomics in a pers(...)
# [*]  Expansive arterial remodeling of the carotid arteries and its eff(...)
# [*]  Strategies for the coronary surgeon to remain “competitive and co(...)
# [*]  Robust Nucleus/Cell Detection and Segmentation in Digital Patholo(...)
# [*]  5th International Symposium on Focused Ultrasound: North Bethesda(...)
# [*]  Korean Guidelines for the Appropriate Use of Cardiac CT(...)
# [*]  Cardiac imaging: working towards fully-automated machine analysis(...)
# [*]  The Coming of Age of Artificial Intelligence in Medicine(...)
# [*]  D-TRANSPOSITION OF THE GREAT ARTERIES: Hot Topics in the Current (...)
# [*]  Status and potential clinical value of a transthoracic evaluation(...)
# [*]  Segmentation and Image Analysis of Abnormal Lungs at CT: Current (...)
# [*]  Structured learning algorithm for detection of nonobstructive and(...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  B - Scientific Sessions(...)
# [*]  Coronary Arteries in Childhood Heart Disease: Implications for Ma(...)
# [*]  MRI Segmentation of the Human Brain: Challenges, Methods, and App(...)
# [*]  Abstracts from the 38th Annual Meeting of the Society of General (...)
# [*]  ECR 2011 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Validation of high temporal resolution spiral phase velocity mapp(...)
# [*]  A Learning-Based Wrapper Method to Correct Systematic Errors in A(...)[*]
#  7th Indonesian Society of Interventional Cardiology Annual Meetin(...)
# [*]  Endothelin(...)
# [*]  The future of off-pump coronary artery bypass grafting: a North A(...)
# [*]  A Review on Segmentation of Positron Emission Tomography Images(...)
# [*]  36th International Symposium on Intensive Care and Emergency Medi(...)
# [*]  Current State of Surgical Myocardial Revascularization(...)
# [*]  Evaluation of a deep learning approach for the segmentation of br(...)
# [*]  Artificial Intelligence Techniques for Automatic Screening of Amb(...)
# [*]  Is endovascular therapy the right choice for treatment of functio(...)
# [*]  In vivo label-free structural and biochemical imaging of coronary(...)
# [*]  Patient-Centered Pain Care Using Artificial Intelligence and Mobi(...)
# [*]  Simultaneous Tumor Segmentation, Image Restoration, and Blur Kern(...)
# [*]  Deep learning for cardiac computer-aided diagnosis: benefits, iss(...)
# [*]  Use of a Novel Artificial Intelligence Platform on Mobile Devices(...)
# [*]  Establishing the Case for Minimally Invasive, Robotic-Assisted CA(...)
# [*]  A review of heart chamber segmentation for structural and functio(...)
# [*]  Stress echo 2020: the international stress echo study in ischemic(...)
# [*]  How artificial intelligence tools can be used to assess individua(...)
# [*]  Deep learning predictions of survival based on MRI in amyotrophic(...)
# [*]  A Review on Automatic Mammographic Density and Parenchymal Segmen(...)
# [*]  Application of pattern recognition tools for classifying acute co(...)
# [*]  Sudden death after normal coronary angiography and possible cause(...)
# [*]  Lynx: Automatic Elderly Behavior Prediction in Home Telecare(...)
# [*]  Deep Learning in Medical Image Analysis(...)
# [*]  Heart Disease and Stroke Statistics—2013 Update: A Report From th(...)
# [*]  ESICM LIVES 2016: part two: Milan, Italy. 1–5 October 2016(...)
# [*]  Interactive Outlining of Pancreatic Cancer Liver Metastases in Ul(...)
# [*]  Reducing unnecessary lab testing in the ICU with artificial intel(...)
# [*]  Advancing the Assessment of Dynamic Psychological Processes(...)
# [*]  Heart Disease and Stroke Statistics—2013 Update: A Report From th(...)
# [*]  Exploring the relationships between epistemic beliefs about medic(...)
# [*]  Vision 20/20: Perspectives on automated image segmentation for ra(...)
# [*]  Tuberculosis control, and the where and why of artificial intelli(...)
# [*]  Distinct Neurocognitive Strategies for Comprehensions of Human an(...)
# [*]  The educational impact of assessment: A comparison of DOPS and MC(...)
# [*]  A Methodology for Texture Feature-based Quality Assessment in Nuc(...)
# [*]  Semiautomated segmentation of head and neck cancers in 18F-FDG PE(...)
# [*]  Computer-Assisted Diagnosis of the Sleep Apnea-Hypopnea Syndrome:(...)
# [*]  Patients’ approaches to students’ learning at a clinical educatio(...)
# [*]  International Society for Therapeutic Ultrasound Conference 2016:(...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  Abstracts from the 36th Annual Meeting of the Society of General (...)
# [*]  Deep into the Brain: Artificial Intelligence in Stroke Imaging(...)
# [*]  Multi-Atlas Segmentation of Biomedical Images: A Survey(...)
# [*]  Current outcomes of off-pump coronary artery bypass grafting: evi(...)
# [*]  Cardiac imaging: working towards fully-automated machine analysis(...)
# [*]  Artificial Intelligence in Mitral Valve Analysis(...)
# [*]  36th International Symposium on Intensive Care and Emergency Medi(...)
# [*]  Comparative performance evaluation of automated segmentation meth(...)
# [*]  Quantification in cardiac MRI: advances in image acquisition and (...)
# [*]  A Survey on Ambient Intelligence in Health Care(...)
# [*]  Beatquency domain and machine learning improve prediction of card(...)
# [*]  Learning Image Context for Segmentation of Prostate in CT-Guided (...)
# [*]  Proceedings of the 3rd IPLeiria’s International Health Congress: (...)
# [*]  Optimal sequence of tests for the mediastinal staging of non-smal(...)
# [*]  Endothelin(...)
# [*]  Computer Vision Techniques for Transcatheter Intervention(...)
# [*]  Non-linear associations between laryngo-pharyngeal symptoms of ga(...)
# [*]  Artificial intelligence in medicine.(...)
# [*]  Two Time Point MS Lesion Segmentation in Brain MRI: An Expectatio(...)
# [*]  B - Scientific Sessions(...)
# [*]  Computerized prediction of intensive care unit discharge after ca(...)
# [*]  Optic Disc and Optic Cup Segmentation Methodologies for Glaucoma (...)
# [*]  Perceived work-related stress and early atherosclerotic changes i(...)
# [*]  Abstracts from the 38th Annual Meeting of the Society of General (...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  Acute Mental Discomfort Associated with Suicide Behavior in a Cli(...)
# [*]  The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)(...)
# [*]  Quantitative Risk Stratification of Oral Leukoplakia with Exfolia(...)
# [*]  Robust parameter extraction for decision support using multimodal(...)
# [*]  [*] A Review on Automatic Mammographic Density and Parenchymal Segmen(...)
# Sudden Cardiac Risk Stratification with Electrocardiographic Indi(...)
# [*]  Improving Low-dose Cardiac CT Images based on 3D Sparse Represent(...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  A Novel Unsupervised Segmentation Quality Evaluation Method for R(...)
# [*]  Prostate Cancer Risk Inflation as a Consequence of Image-targeted(...)
# [*]  Abstracts for the 15th International Congress on Schizophrenia Re(...)
# [*]  Deep Patient: An Unsupervised Representation to Predict the Futur(...)
# [*]  Vision 20/20: Perspectives on automated image segmentation for ra(...)
# [*]  Quantification in cardiac MRI: advances in image acquisition and (...)
# [*]  Modelling the pre-assessment learning effects of assessment: evid(...)
# [*]  A Review on Automatic Mammographic Density and Parenchymal Segmen(...)
# [*]  A review of heart chamber segmentation for structural and functio(...)
# [*]  Application of Deep Learning in Automated Analysis of Molecular I(...)
# [*]  Medical Student and Tutor Perceptions of Video Versus Text in an (...)
# [*]  A targeted next‐generation sequencing in the molecular risk strat(...)
# [*]  Multi-Atlas Segmentation of Biomedical Images: A Survey(...)
# [*]  ESICM LIVES 2016: part three: Milan, Italy. 1–5 October 2016(...)
# [*]  Deep Learning for Brain MRI Segmentation: State of the Art and Fu(...)
# [*]  Migration and stratification(...)
# [*]  Deep learning of joint myelin and T1w MRI features in normal-appe(...)
# [*]  The role of alpha-rhythm states in perceptual learning: insights (...)
# [*]  How artificial intelligence tools can be used to assess individua(...)
# [*]  Pixel-Level Deep Segmentation: Artificial Intelligence Quantifies(...)
# [*]  Overcoming intratumoural heterogeneity for reproducible molecular(...)
# [*]  Quantitative assessment of susceptibility weighted imaging proces(...)
# [*]  Deep into the Brain: Artificial Intelligence in Stroke Imaging(...)
# [*]  Computer Vision Techniques for Transcatheter Intervention(...)
# [*]  Semantic Relations for Problem-Oriented Medical Records(...)
# [*]  Optimization of Prostate Biopsy: the Role of Magnetic Resonance I(...)
# [*]  25th Annual Computational Neuroscience Meeting: CNS-2016(...)
# [*]  Comparison of visual grading and free-response ROC analyses for a(...)
# [*]  Computerized prediction of intensive care unit discharge after ca(...)
# [*]  ECR 2012 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Novel Molecular Imaging Approaches to Abdominal Aortic Aneurysm R(...)
# [*]  Partitioning Histopathological Images: An Integrated Framework fo(...)
# [*]  WFITN 2015 Abstracts Oral Abstracts(...)
# [*]  Fast parallel image registration on CPU and GPU for diagnostic cl(...)
# [*]  A Review for Detecting Gene-Gene Interactions Using Machine Learn(...)
# [*]  Early Molecular Stratification of High-risk Primary Biliary Chola(...)
# [*]  36th International Symposium on Intensive Care and Emergency Medi(...)
# [*]  Myocardial Infarct Segmentation from Magnetic Resonance Images fo(...)
# [*]  A Review of Algorithms for Segmentation of Optical Coherence Tomo(...)
# [*]  Variation in CACNA1C is Associated with Amygdala Structure and Fu(...)
# [*]  Major clinical research advances in gynecologic cancer in 2016: 1(...)
# [*]  Highly automatic quantification of myocardial oedema in patients (...)
# [*]  Task-based measures of image quality and their relation to radiat(...)
# [*]  Automatic segmentation of right ventricular ultrasound images usi(...)
# [*]  Dynamics of study strategies and teacher regulation in virtual pa(...)
# [*]  Metabolomics for the masses: The future of metabolomics in a pers(...)
# [*]  The EU-AIMS Longitudinal European Autism Project (LEAP): design a(...)
# [*]  Combining Personality Traits with Traditional Risk Factors for Co(...)
# [*]  2014 Update of the Alzheimer’s Disease Neuroimaging Initiative: A(...)
# [*]  Relevance of deep learning to facilitate the diagnosis of HER2 st(...)
# [*]  A Risk Prediction Model for Screening Bacteremic Patients: A Cros(...)
# [*]  Using the virtual reality device Oculus Rift for neuropsychologic(...)
# [*]  Abstracts for the 15th International Congress on Schizophrenia Re(...)
# [*]  Advanced method used for hypertension’s risk factors stratiﬁcatio(...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  25th Annual Computational Neuroscience Meeting: CNS-2016(...)
# [*]  Nodular Thyroid Disease and Thyroid Cancer in the Era of Precisio(...)
# [*]  French Intensive Care Society, International congress – Réanimati(...)
# [*]  Comprehensive Brain MRI Segmentation in High Risk Preterm Newborn(...)
# [*]  Computed Tomography-Based High-Risk Coronary Plaque Score to Pred(...)
# [*]  Predicting outcomes in patients with perforated gastroduodenal ul(...)
# [*]  Highly automatic quantification of myocardial oedema in patients (...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  Incorporating temporal EHR data in predictive models for risk str(...)
# [*]  Manual versus Automated Carotid Artery Plaque Component Segmentat(...)
# [*]  Proceedings of the 8th Annual Conference on the Science of Dissem(...)
# [*]  Computational purification of individual tumor gene expression pr(...)
# [*]  Automated Detection of Lupus White Matter Lesions in MRI(...)
# [*]  Estimation of breast percent density in raw and processed full fi(...)
# [*]  Simple Scoring System and Artificial Neural Network for Knee Oste(...)
# [*]  Precision Radiology: Predicting longevity using feature engineeri(...)
# [*]  Clinical and pathological implications of miRNA in bladder cancer(...)
#  [*]  Geodesic Distance Algorithm for Extracting the Ascending Aorta fr(...)
# [*]  Heart Rate Variability Dynamics for the Prognosis of Cardiovascul(...)
# [*]  Computer-Aided Detection of Prostate Cancer with MRI: Technology (...)
# [*]  The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)(...)
# [*]  Risk Stratification of ICU Patients Using Topic Models Inferred f(...)
# [*]  Clinical prediction from structural brain MRI scans: A large-scal(...)
# [*]  Recurrent Glioblastoma Treated with Bevacizumab: Contrast-enhance(...)
# [*]  Segmentation of Image Data from Complex Organotypic 3D Models of (...)
# [*]  Endothelin(...)
# [*]  Airway Tree Segmentation in Serial Block-Face Cryomicrotome Image(...)
# [*]  Improving the Power of GWAS and Avoiding Confounding from Populat(...)
# [*]  A Novel Unsupervised Segmentation Quality Evaluation Method for R(...)
# [*]  Enabling Privacy-Preserving GWAS in Heterogeneous Human Populatio(...)
# [*]  Contour-Driven Atlas-Based Segmentation(...)
# [*]  Potential usefulness of apolipoprotein A2 isoforms for screening (...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  Evaluation of a deep learning approach for the segmentation of br(...)
# [*]  ECR 2012 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Deep learning predictions of survival based on MRI in amyotrophic(...)
# [*]  Prefrontal Inefficiency Is Associated With Polygenic Risk for Sch(...)
# [*]  Multi-Atlas Segmentation of Biomedical Images: A Survey(...)
# [*]  Cardiac imaging: working towards fully-automated machine analysis(...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  Pixel-Level Deep Segmentation: Artificial Intelligence Quantifies(...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  Automatic segmentation of head and neck CT images for radiotherap(...)
# [*]  Assessment of Myocardial Scarring Improves Risk Stratification in(...)
# [*]  Multimodality image fusion for diagnosing coronary artery disease(...)
# [*]  A Methodology for Texture Feature-based Quality Assessment in Nuc(...)
# [*]  Precision Radiology: Predicting longevity using feature engineeri(...)
# [*]  Optic Disc and Optic Cup Segmentation Methodologies for Glaucoma (...)
# [*]  A Deep Learning-Based Radiomics Model for Prediction of Survival (...)
# [*]  Nearly Automatic Segmentation of Hippocampal Subfields in In Vivo(...)
# [*]  CT Angiography after 20 Years: A Transformation in Cardiovascular(...)
# [*]  Artificial intelligence techniques applied to the development of (...)
# [*]  Breast cancer prediction using genome wide single nucleotide poly(...)
# [*]  Spinal cord grey matter segmentation challenge(...)
# [*]  How artificial intelligence tools can be used to assess individua(...)
# [*]  A comparative study of machine learning methods for time-to-event(...)
# [*]  Optical coherence tomography angiography: Technical principles an(...)
# [*]  Abstracts for the 15th International Congress on Schizophrenia Re(...)
# [*]  Lynx: Automatic Elderly Behavior Prediction in Home Telecare(...)
# [*]  A Modular Hierarchical Approach to 3D Electron Microscopy Image S(...)
# [*]  Quantitative Risk Stratification of Oral Leukoplakia with Exfolia(...)
# [*]  Aqueous Angiography: Real-Time and Physiologic Aqueous Humor Outf(...)
# [*]  An artificial intelligence tool to predict fluid requirement in t(...)
# [*]  Abstracts from the 38th Annual Meeting of the Society of General (...)
# [*]  Vertebral body segmentation with GrowCut: Initial experience, wor(...)
# [*]  Coronary CT Angiography in Heavily Calcified Coronary Arteries: I(...)
# [*]  Reducing unnecessary lab testing in the ICU with artificial intel(...)
# [*]  Coronary CT angiography: current status and continuing challenges(...)
# [*]  Computer Vision Techniques for Transcatheter Intervention(...)
# [*]  Modeling the Effects of Light and Sucrose on In Vitro Propagated (...)
# [*]  Reading the Mind in the Eyes or Reading between the Lines? Theory(...)
# [*]  Methods and algorithms for optical coherence tomography-based ang(...)
# [*]  Computer-Assisted Diagnosis of the Sleep Apnea-Hypopnea Syndrome:(...)
# [*]  Iterative framework for the joint segmentation and CT synthesis o(...)
# [*]  The Multimodal Brain Tumor Image Segmentation Benchmark (BRATS)(...)
# [*]  Improved image reconstruction of low-resolution multichannel phas(...)
# [*]  Identification of Alfalfa Leaf Diseases Using Image Recognition T(...)
# [*]  Deep into the Brain: Artificial Intelligence in Stroke Imaging(...)
# [*]  Advanced image processing for optical coherence tomographic angio(...)
# [*]  Manual-Protocol Inspired Technique for Improving Automated MR Ima(...)
# [*]  Task-based measures of image quality and their relation to radiat(...)
# [*]  Artificial intelligence in medicine.(...)
# [*]  Unmanned Aerial Vehicles (UAVs) and Artificial Intelligence Revol(...)
# [*]  Location Sensitive Deep Convolutional Neural Networks for Segment(...)
# [*]  Analysis of Fundus Fluorescein Angiogram Based on the Hessian Mat(...)
# [*]  ESICM LIVES 2016: part two: Milan, Italy. 1–5 October 2016(...)
# [*]  Altering Visual Perception Abnormalities: A Marker for Body Image(...)
# [*]  Computerized prediction of intensive care unit discharge after ca(...)
# [*]  Nonrigid Image Registration in Digital Subtraction Angiography Us(...)
# [*]  Automated brain tumour detection and segmentation using superpixe(...)
# [*]  Patient-Centered Pain Care Using Artificial Intelligence and Mobi(...)
# [*]  Associations of CAIDE Dementia Risk Score with MRI, PIB-PET measu(...)
# [*]  Comparison of amplitude-decorrelation, speckle-variance and phase(...)
# [*]  Neuronal Reward and Decision Signals: From Theories to Data(...)
# [*]  Computer-Aided Diagnosis Systems for Lung Cancer: Challenges and (...)
# [*]  French Intensive Care Society, International congress – Réanimati(...)
# [*]  On the Applicability of Brain Reading for Predictive Human-Machin(...)
# [*]  Multi-phase rotational angiography of the left ventricle to assis(...)
# [*]  Korean Guidelines for the Appropriate Use of Cardiac CT(...)
# [*]  Efficacy of a Web-based Intelligent Tutoring System for Communica(...)
# [*]  Artificial Intelligence-Assisted Online Social Therapy for Youth (...)
# [*]  Impact of image quality on OCT angiography based quantitative mea(...)
# [*]  Medical Students Perceive Better Group Learning Processes when La(...)
# [*]  Advanced image processing for optical coherence tomographic angio(...)
# [*]  Aqueous Angiography–Mediated Guidance of Trabecular Bypass Improv(...)
# [*]  A Review of Intelligent Driving Style Analysis Systems and Relate(...)
# [*]  Predicting clinical outcomes from large scale cancer genomic prof(...)
# [*]  ECR 2011 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Contour-Driven Atlas-Based Segmentation(...)
# [*]  UEG Week 2014 Poster Presentations(...)
# [*]  Enhanced characterization of calcified areas in intravascular ult(...)
# [*]  Breast cancer risk variants at 6q25 display different phenotype a(...)
# [*]  Application of Deep Learning in Automated Analysis of Molecular I(...)
# [*]  Cerebral Artery Signal Transduction Mechanisms: Developmental Cha(...)
# [*]  3D multimodal cardiac data reconstruction using angiography and c(...)
# [*]  Recent Advances in 3D Time-Resolved Contrast-Enhanced MR Angiogra(...)
# [*]  Precision Radiology: Predicting longevity using feature engineeri(...)
# [*]  Automated Quantitative Nuclear Cardiology Methods(...)
# [*]  Retinal Vessel Segmentation: An Efficient Graph Cut Approach with(...)
# [*]  Abstracts for the 15th International Congress on Schizophrenia Re(...)
# [*]  2014 Joint ACTRIMS-ECTRIMS Meeting (MSBoston 2014) MS Journal Onl(...)
# [*]  Diagnostic performance of 320-slice multidetector computed tomogr(...)
# [*]  Multi-Atlas Segmentation of Biomedical Images: A Survey(...)
# [*]  Automatic centerline extraction of coronary arteries in coronary (...)
# [*]  ACUTE RETINAL ARTERIAL OCCLUSIVE DISORDERS(...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  Computer Vision Techniques for Transcatheter Intervention(...)
# [*]  The fundus photo has met its match: optical coherence tomography (...)
# [*]  B - Scientific Sessions(...)
# [*]   2014 Guidelines of Taiwan Society of Cardiology (TSOC) for the M(...)
# [*]  A review of heart chamber segmentation for structural and functio(...)
# [*]  Comparative analysis of fluorescent angiography, computed tomogra(...)
# [*]  UEG Week 2014 Poster Presentations(...)
# [*]  A Fast and Fully Automatic Method for Cerebrovascular Segmentatio(...)
# [*]  Meaning of Interior Tomography(...)
# [*]  Multi-categorical deep learning neural network to classify retina(...)
# [*]  25th Annual Computational Neuroscience Meeting: CNS-2016(...)
# [*]  Analysis of Fundus Fluorescein Angiogram Based on the Hessian Mat(...)
# [*]  Frostbite: Spectrum of Imaging Findings and Guidelines for Manage(...)
# [*]  Automated Quantitative Nuclear Cardiology Methods(...)
# [*]  A study of the progression of damage in an axially loaded Branta (...)
# [*]  User-guided segmentation for volumetric retinal optical coherence(...)
# [*]  Applying artificial intelligence to disease staging: Deep learnin(...)
# [*]  Aqueous Angiography–Mediated Guidance of Trabecular Bypass Improv(...)
# [*]  Artificial intelligence: Neural network model as the multidiscipl(...)
# [*]  Fast virtual histology using X-ray in-line phase tomography: appl(...)
# [*]  Optic Disc and Optic Cup Segmentation Methodologies for Glaucoma (...)
# [*]  Machine Learning for Medical Imaging(...)
# [*]  Analysis of coronary angiography related psychophysiological resp(...)
# [*]  Deep-learning: investigating deep neural networks hyper-parameter(...)
# [*]  Compressive sensing in medical imaging(...)
# [*]  Effect of Computerized Clinical Decision Support on the Use and Y(...)
# [*]  Methods for 2D and 3D Endobronchial Ultrasound Image Segmentation(...)
# [*]  Abstracts from the 37th Annual Meeting of the Society of General (...)
# [*]  High-Efficiency SPECT MPI: Comparison of Automated Quantification(...)
# [*]  Prospective stratification of patients at risk for emergency depa(...)
# [*]  Deep Learning- and Transfer Learning-Based Super Resolution Recon(...)
# [*]  Iterative Reconstruction for X-Ray Computed Tomography using Prio(...)
# [*]  Multi-phase rotational angiography of the left ventricle to assis(...)
# [*]  Computer assisted diagnosis in renal nuclear medicine: rationale,(...)
# [*]  Resonant Cholinergic Dynamics in Cognitive and Motor Decision-Mak(...)
# [*]  Structured learning algorithm for detection of nonobstructive and(...)
# [*]  Graph-Based IVUS Segmentation with Efficient Computer-Aided Refin(...)
# [*]  Prediction of Revascularization after Myocardial Perfusion SPECT (...)
# [*]  X-ray computed tomography datasets for forensic analysis of verte(...)
# [*]  Classification of CT Pulmonary Angiography Reports by Presence, C(...)
# [*]  Abstracts from the 37th Annual Meeting of the Society of General (...)
# [*]  Fully automatic multi-atlas segmentation of CTA for partial volum(...)
# [*]  Mode decomposition evolution equations(...)
# [*]  Advances in imaging technologies for planning breast reconstructi(...)
# [*]  Direct comparison of MRI and X-ray CT technologies for 3D imaging(...)
# [*]  Automated volumetric segmentation of retinal fluid on optical coh(...)
# [*]  Effects of damping-off caused by Rhizoctonia solani anastomosis g(...)
# [*]  Cardiac imaging: working towards fully-automated machine analysis(...)
# [*]  WFITN 2015 Abstracts Oral Abstracts(...)
# [*]  Three-dimensional quantitative fracture analysis of tight gas san(...)
# [*]  A Review of Algorithms for Segmentation of Optical Coherence Tomo(...)
# [*]  Indocyanine green-based fluorescent angiography in breast reconst(...)
# [*]  Altered Brain Activation during Emotional Face Processing in Rela(...)
# [*]  A Comprehensive Texture Segmentation Framework for Segmentation o(...)
# [*]  Nanoparticle Contrast Agents for Computed Tomography: A Focus on (...)
# [*]  Review of optical coherence tomography based angiography in neuro(...)
# [*]  Assessment of a four-view mammographic image feature based fusion(...)
# [*]  In vivo imaging of retinal hemodynamics with OCT angiography and (...)
# [*]  Improved Accuracy of Myocardial Perfusion SPECT for the Detection(...)
# [*]  Radiomics-based differentiation of lung disease models generated (...)
# [*]  ECR 2012 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Deep Convolutional Neural Networks for Computer-Aided Detection: (...)
# [*]  Validation of Macular Choroidal Thickness Measurements from Autom(...)
# [*]  Comparison of Fully Automated Computer Analysis and Visual Scorin(...)
# [*]  XXIV World Allergy Congress 2015: Seoul, Korea. 14-17 October 201(...)
# [*]  How little data is enough? Phase-diagram analysis of sparsity-reg(...)
# [*]  Imaging and graphing of cortical vasculature using dynamically fo(...)
# [*]  Uncovering and Improving Upon the Inherent Deficiencies of Radiol(...)
# [*]  Low-dose X-ray computed tomography image reconstruction with a co(...)
# [*]  Cardiac type of total anomalous pulmonary venous connection: diag(...)
# [*]  Impact of the Learning Curve for Endoscopic Vein Harvest on Condu(...)
# [*]  Learning Vector Quantization Neural Networks Improve Accuracy of (...)
# [*]  3D Histopathology—a Lung Tissue Segmentation Workflow for Microfo(...)
# [*]  Effects of X-Ray Dose On Rhizosphere Studies Using X-Ray Computed(...)
# [*]  Direct comparison of MRI and X-ray CT technologies for 3D imaging(...)
# [*]  Sudden death after normal coronary angiography and possible cause(...)
# [*]  Direct Quantification of Post-Stress-Rest Left Ventricular Motion(...)
# [*]  3D chemical imaging in the laboratory by hyperspectral X-ray comp(...)
# [*]  Abstracts from the 37th Annual Meeting of the Society of General (...)
# [*]  Decision support systems for clinical radiological practice — tow(...)
# [*]  Fast virtual histology using X-ray in-line phase tomography: appl(...)
# [*]  ℓ0 Gradient Minimization Based Image Reconstruction for Limited-A(...)
# [*]  Progress testing in the medical curriculum: students’ approaches (...)
# [*]  Rapid phenotyping of crop root systems in undisturbed field soils(...)
# [*]  Fault Diagnosis Based on Chemical Sensor Data with an Active Deep(...)
# [*]  Chronic Heart Failure Follow-up Management Based on Agent Technol(...)
# [*]  Three-Dimensional Mapping of Soil Chemical Characteristics at Mic(...)
# [*]  Correlation of X-Ray Computed Tomography with Quantitative Nuclea(...)
# [*]  Machine Learning and Radiology(...)
# [*]  Multiscale correlative tomography: an investigation of creep cavi(...)
# [*]  Abstracts from the 38th Annual Meeting of the Society of General (...)
# [*]  Abstracts for the 15th International Congress on Schizophrenia Re(...)
# [*]  A nanocomposite of Au-AgI core/shell dimer as a dual-modality con(...)
# [*]  Quantitative analysis of microscopic X-ray computed tomography im(...)
# [*]  WFITN 2015 Abstracts: Oral Expositions(...)
# [*]  Laboratory x-ray micro-computed tomography: a user guideline for (...)
# [*]  A Review on Segmentation of Positron Emission Tomography Images(...)
# [*]  Proceedings of the 3rd IPLeiria’s International Health Congress: (...)
# [*]  Diagnostic accuracy of an artificial neural network compared with(...)
# [*]  Radiomics-based differentiation of lung disease models generated (...)
# [*]  ESICM LIVES 2016: part one: Milan, Italy. 1-5 October 2016(...)
# [*]  Positioning Standardized Acupuncture Points on the Whole Body Bas(...)
# [*]  X-ray computed tomography datasets for forensic analysis of verte(...)
# [*]  Abstracts from the 38th Annual Meeting of the Society of General (...)
# [*]  Three-dimensional quantitative fracture analysis of tight gas san(...)
# [*]  Development and Validation of a Stratification Tool for Predictin(...)
# [*]  Assessing the influence of the rhizosphere on soil hydraulic prop(...)
# [*]  Machine Learning Improves Risk Stratification After Acute Coronar(...)
# [*]  Evaluation of single-photon emission computed tomography images o(...)
# [*]  Segmentation and Image Analysis of Abnormal Lungs at CT: Current (...)
# [*]  Computational Phenotype Discovery Using Unsupervised Feature Lear(...)
# [*]  Abstracts from the 38th Annual Meeting of the Society of General (...)
# [*]  Joint analysis of histopathology image features and gene expressi(...)
# [*]  Automating Construction of Machine Learning Models With Clinical (...)
# [*]  Compressive sensing in medical imaging(...)
# [*]  Detection and Segmentation of Erythrocytes in Blood Smear Images (...)
# [*]  5th International Symposium on Focused Ultrasound: North Bethesda(...)
# [*]  Computational neurorehabilitation: modeling plasticity and learni(...)
# [*]  High-kVp Assisted Metal Artifact Reduction for X-ray Computed Tom(...)
# [*]  Iterative framework for the joint segmentation and CT synthesis o(...)
# [*]  UEG Week 2013 Poster Presentations(...)
# [*]  Three-Dimensional Mapping of Soil Chemical Characteristics at Mic(...)
# [*]  Relevance of deep learning to facilitate the diagnosis of HER2 st(...)
# [*]  X-ray imaging methods for internal quality evaluation of agricult(...)
# [*]  36th International Symposium on Intensive Care and Emergency Medi(...)
# [*]  Morphological Characterisation of Unstained and Intact Tissue Mic(...)
# [*]  Interpretable Deep Models for ICU Outcome Prediction(...)
# [*]  Positioning Standardized Acupuncture Points on the Whole Body Bas(...)
# [*]  Abstracts from the 36th Annual Meeting of the Society of General (...)
# [*]  Realistic 3D Computer Model of the Gerbil Middle Ear, Featuring A(...)
# [*]  Three-dimensional measurement of small inner surface profiles usi(...)
# [*]  ℓ0 Gradient Minimization Based Image Reconstruction for Limited-A(...)
# [*]  The Brain as a Distributed Intelligent Processing System: An EEG (...)
# [*]  Mode decomposition evolution equations(...)
# [*]  ECR 2012 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Deep Learning in Medical Image Analysis(...)
# [*]  A Dictionary Learning Approach with Overlap for the Low Dose Comp(...)
# [*]  Dictionary-Learning-Based Reconstruction Method for Electron Tomo(...)
# [*]  UEG Week 2015 Poster Presentations(...)
# [*]  Improving Low-dose Cardiac CT Images based on 3D Sparse Represent(...)
# [*]  CT brush and CancerZap!: two video games for computed tomography (...)
# [*]  Integrating Dimension Reduction and Out-of-Sample Extension in Au(...)
# [*]  Modelling the pre-assessment learning effects of assessment: evid(...)
# [*]  Distinct Neurocognitive Strategies for Comprehensions of Human an(...)
# [*]  UEG Week 2014 Poster Presentations(...)
# [*]  3D Forward and Back-Projection for X-Ray CT Using Separable Footp(...)
# [*]  Optimal sequence of tests for the mediastinal staging of non-smal(...)
# [*]  Deep into the Brain: Artificial Intelligence in Stroke Imaging(...)
# [*]  ECR 2012 Book of Abstracts - B - Scientific Sessions(...)
# [*]  Advances in Nuclear Cardiac Instrumentation with a View Towards R(...)
# [*]  Low-Dose X-ray CT Reconstruction via Dictionary Learning(...)
# [*]  Sampling from Determinantal Point Processes for Scalable Manifold(...)
# [*]  Comparing algorithms for automated vessel segmentation in compute(...)
# [*]  Dual-Dictionary Learning-Based Iterative Image Reconstruction for(...)
# [*]  Abstracts from the 37th Annual Meeting of the Society of General (...)
# [*]  Multiagent cooperation and competition with deep reinforcement le(...)
# [*]  Learning to learn about uncertain feedback(...)
# [*]  Investigation of gastric cancers in nude mice using X-ray in-line(...)
# [*]  Dual-Dictionary Learning-Based Iterative Image Reconstruction for(...)
# [*]  Gaussian diffusion sinogram inpainting for X-ray CT metal artifac(...)
# [*]  Diffuse Optics for Tissue Monitoring and Tomography(...)
# [*]  Non-destructive, high-content analysis of wheat grain traits usin(...)
# [*]  Quantifying Mesoscale Neuroanatomy Using X-Ray Microtomography(...)
# [*]  ECR 2012 Book of Abstracts - A - Postergraduate Educational Progr(...)
# [*]  Three-dimensional measurement of small inner surface profiles usi(...)
# [*]  ECR 2011 Book of Abstracts - A - Postgraduate Educational Program(...)
# [*]  Structured learning algorithm for detection of nonobstructive and(...)
# [*]  Tungsten Oxide Nanorods: An Efficient Nanoplatform for Tumor CT I(...)
# [*]   Three-Dimensional Modelling of the Middle-Ear Ossicular Chain Us(...)
# [*]  Fifty years of computer analysis in chest imaging: rule-based, ma(...)
# [*]  Deep feature learning for automatic tissue classification of coro(...)
# Tempo de execução: 1000.61823678
# [*] fim: resultados salvos em thread_stems2017-11-30-16:30:19.409350.txt

# %% [markdown]
# ### Selecionando artigos interativamente

# %%
import webbrowser
from ast import literal_eval
import re

with open(filename,'r') as myf:
    print '[*] Extraindo artigos de', filename
    s = myf.read()
    stems = literal_eval(s)
for key in stems.keys():
    print '>>>>>>>>>', key
    i = 0
    while i < len(stems[key]):
        article = stems[key][i]
        print article['title'],'\n'
        print article['kwd'],'\n'
        print article['p'],'\n'
        
        apagar = re.compile("(apa|del|rem)",re.IGNORECASE)
        url = re.compile("(url|link|ender|site|abr)",re.IGNORECASE)
        proximo = re.compile("(con|ava|pro|nex)",re.IGNORECASE)
        sair = re.compile("(sai|lea|exi|fin)",re.IGNORECASE)
        
        match = False
        while not match:
            act = raw_input("Ação ")
            if apagar.match(act):
                print 'apagando'
                stems[key].remove(article)
                match = True
                i -= 1
            elif url.match(act):
                print 'abrindo'
                i -= 1
                webbrowser.open(article['url'])
                match = True
            elif proximo.match(act) or act == '':
                print 'continuando'
                match = True
                continue
            elif sair.match(act):
                i = len(stems[key])
                match = True
            else:
                print 'invalido!'
        i += 1
    filename = "stems" + str(datetime.now()).replace(' ','-') + '.txt'
    with open(filename, 'w') as myf:
        myf.write(str(stems))
        print '[*] resultados salvos em',filename
# Out:
# [*] Extraindo artigos de stems2017-11-29-22:14:23.934958.txt
# Cardiac magnetic resonance and computed tomography angiography for clinical imaging of stable coronary artery disease. Diagnostic classification and risk stratification
#
# coronary artery disease, atherosclerotic plaque, coronary computed tomography, cardiac magnetic resonance, risk stratification
#
# Despite advances in the pharmacologic and interventional treatment of coronary artery disease (CAD), atherosclerosis remains the leading cause of death in Western societies. X-ray coronary angiography has been the modality of choice for diagnosing the presence and extent of CAD. However, this technique is invasive and provides limited information on the composition of atherosclerotic plaque. Coronary computed tomography angiography (CCTA) and cardiac magnetic resonance (CMR) have emerged as promising non-invasive techniques for the clinical imaging of CAD. Hereby, CCTA allows for visualization of coronary calcification, lumen narrowing and atherosclerotic plaque composition. In this regard, data from the CONFIRM Registry recently demonstrated that both atherosclerotic plaque burden and lumen narrowing exhibit incremental value for the prediction of future cardiac events. However, due to technical limitations with CCTA, resulting in false positive or negative results in the presence of severe calcification or motion artifacts, this technique cannot entirely replace invasive angiography at the present time. CMR on the other hand, provides accurate assessment of the myocardial function due to its high spatial and temporal resolution and intrinsic blood-to-tissue contrast. Hereby, regional wall motion and perfusion abnormalities, during dobutamine or vasodilator stress, precede the development of ST-segment depression and anginal symptoms enabling the detection of functionally significant CAD. While CT generally offers better spatial resolution, the versatility of CMR can provide information on myocardial function, perfusion, and viability, all without ionizing radiation for the patients. Technical developments with these 2 non-invasive imaging tools and their current implementation in the clinical imaging of CAD will be presented and discussed herein.The authors declare that the research was conducted in the absence of any commercial or financial relationships that could be construed as a potential conflict of interest.
#
# Ação apaga
# apagando
# Noninvasive FFR derived from coronary CT angiography in the management of coronary artery disease: technology and clinical update
#
# fractional flow reserve, coronary computed tomographic angiography, FFRCT, cFFR
#
# After a decade of clinical use of coronary computed tomographic angiography (CCTA) to evaluate the anatomic severity of coronary artery disease, new methods of deriving functional information from CCTA have been developed. These methods utilize the anatomic information provided by CCTA in conjunction with computational fluid dynamics to calculate fractional flow reserve (FFR) values from CCTA image data sets. Computed tomography-derived FFR (CT-FFR) enables the identification of lesion-specific drop noninvasively. A three-dimensional CT-FFR modeling technique, which provides FFR values throughout the coronary tree (HeartFlow FFRCT analysis), has been validated against measured FFR and is now approved by the US Food and Drug Administration for clinical use. This technique requires off-site supercomputer analysis. More recently, a one-dimensional computational analysis technique (Siemens cFFR), which can be performed on on-site workstations, has been developed and is currently under investigation. This article reviews CT-FFR technology and clinical evidence for its use in stable patients with suspected coronary artery disease.Intermediate degrees of stenosis (30%–70%) present the greatest challenge in the diagnosis of CAD. Since hemodynamically significant lesions are occasionally observed in intermediate lesions with <70% stenosis,13 the use of invasive FFR is recommended to evaluate the function of intermediate coronary lesions as a class IIa indication.6 However, given the relatively lower prevalence of lesion-specific pressure drop caused by intermediate stenosis compared to that of severe stenosis in the FAME study,13 CT-derived FFR would be of great use for assessing the functional significance of intermediate lesions to avoid unnecessary ICA and help in treatment decision making. Table 2 provides a summary of the studies of FFRCT and cFFR. Similar to the overall diagnostic accuracy of CT-derived FFR, all studies demonstrated high diagnostic performance for intermediate stenosis, with the highest accuracy and specificity for FFRCT.24,31,38,39
#
# Ação apaga
# apagando
# Assessment of stable coronary artery disease by cardiovascular magnetic resonance imaging: Current and emerging techniques
#
# Cardiovascular magnetic resonance, Coronary heart disease, Myocardial perfusion, Viability, Prognosis
#
# Coronary artery disease (CAD) is a leading cause of death and disability worldwide. Cardiovascular magnetic resonance (CMR) is established in clinical practice guidelines with a growing evidence base supporting its use to aid the diagnosis and management of patients with suspected or established CAD. CMR is a multi-parametric imaging modality that yields high spatial resolution images that can be acquired in any plane for the assessment of global and regional cardiac function, myocardial perfusion and viability, tissue characterisation and coronary artery anatomy, all within a single study protocol and without exposure to ionising radiation. Advances in technology and acquisition techniques continue to progress the utility of CMR across a wide spectrum of cardiovascular disease, and the publication of large scale clinical trials continues to strengthen the role of CMR in daily cardiology practice. This article aims to review current practice and explore the future directions of multi-parametric CMR imaging in the investigation of stable CAD.Although 1.5T is remains the standard field strength used in clinical CMR, imaging at a higher field strength of 3.0T offers increased signal to noise and contrast to noise ratios thereby giving improved spatial and temporal enhancement[27]. Consequently the diagnostic accuracy of perfusion imaging at 3.0T may be improved, and in a small direct comparison of CMR perfusion at 1.5T, 3.0T (n = 61) showed greater diagnostic accuracy in both single vessel (AUC: 0.89 vs 0.70; P < 0.05) and multi-vessel disease (AUC: 0.95 vs 0.82, P < 0.05)[28]. Furthermore, 3.0T has been compared to 1.5T using FFR as reference standard, corroborating it’s superior diagnostic accuracy[29,30]. The higher 3.0T field strength does however pose challenges with greater field inhomogeneity, susceptibility artefacts and higher local energy deposition. Also, many implants deemed “MR compatible” at 1.5T cannot be scanned at 3.0T[31]. These issues are however being overcome with improved technology and the use of multi-transmit radiofrequency CMR techniques improving field homogeneity[32].
#
# Ação apaga
# apagando
# Total Coronary Atherosclerotic Plaque Burden Assessment by CT Angiography for Detecting Obstructive Coronary Artery Disease Associated with Myocardial Perfusion Abnormalities
#
# -
#
# Total atherosclerotic plaque burden assessment by CT angiography (CTA) is a promising tool for diagnosis and prognosis of coronary artery disease (CAD) but its validation is restricted to small clinical studies. We tested the feasibility of semi-automatically derived coronary atheroma burden assessment for identifying patients with hemodynamically significant CAD in a large cohort of patients with heterogenous characteristics.This study focused on the CTA component of the CORE320 study population. A semi-automated contour detection algorithm quantified total coronary atheroma volume defined as the difference between vessel and lumen volume. Percent atheroma volume (PAV = [total atheroma volume/total vessel volume]×100) was the primary metric for assessment (n=374). The area under the receiver operating characteristic curve (AUC) determined the diagnostic accuracy for identifying patients with hemodynamically significant CAD defined as ≥50% stenosis by quantitative coronary angiography and associated myocardial perfusion abnormality by SPECT.

# %%
filename
# Out:
# 'thread_stems2017-11-30-16:30:19.409350.txt'
